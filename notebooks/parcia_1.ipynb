# %%
# PARCIAL 1 ELECTIVA I 
# JONATHAN ROJAS DESCANSE - MAICOL GALLEGO

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Links a los conjuntos de datos
url_cgsse ='https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/cgsse.CSV'
url_ocupados = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV'
url_ft ='https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV'
url_desocupados = 'https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV'

# %%
# CGSSE
df_cgsse = pd.read_csv(url_cgsse, encoding='latin-1', sep=';', 
                       low_memory=False)

#Ocupados
df_ocupados=pd.read_csv(url_ocupados,encoding='latin-1',sep=';',
                        low_memory=False)

#Fuerza de trabajo
df_ft=pd.read_csv(url_ft,
                  encoding='latin-1',sep=';',low_memory=False)
#No ocupados
df_desocupados=pd.read_csv(url_desocupados,encoding='latin-1',
                           sep=';',low_memory=False)

# %%
df_cgsse
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     10
# 1      20250626    6  2025     8238974            1      2      1     10
# 2      20250626    6  2025     8238975            1      1      1     10
# 3      20250626    6  2025     8238975            1      2      1     10
# 4      20250626    6  2025     8238975            1      3      1     10
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 67851  20250626    6  2025     8283060            1      1      1     10
# 67852  20250626    6  2025     8283060            1      2      1     10
# 67853  20250626    6  2025     8283062            1      1      1     10
# 67854  20250626    6  2025     8283062            1      2      1     10
# 67855  20250626    6  2025     8283062            1      3      1     10
#
#        AREA  CLASE  ...  P6170  P3041  P3042  P3042S1  P3042S2  P3043  \
# 0       NaN      2  ...    2.0    NaN    5.0      2.0      NaN    2.0
# 1       NaN      2  ...    2.0    NaN    5.0      1.0      NaN    1.0
# 2       NaN      2  ...    2.0    NaN    3.0      3.0      NaN    NaN
# 3       NaN      2  ...    2.0    NaN    1.0      0.0      NaN    NaN
# 4       NaN      2  ...    2.0    NaN    1.0      0.0      NaN    NaN
# ...     ...    ...  ...    ...    ...    ...      ...      ...    ...
# 67851  88.0      1  ...    2.0    NaN    5.0      2.0      NaN    2.0
# 67852  88.0      1  ...    2.0    NaN    5.0      2.0      NaN    2.0
# 67853  94.0      1  ...    2.0    NaN    3.0      3.0      NaN    NaN
# 67854  94.0      1  ...    2.0    NaN    3.0      2.0      NaN    NaN
# 67855  94.0      1  ...    2.0    NaN    5.0      2.0      NaN    2.0
#
#        P3043S1  P3038  P3039  POB_MAY18
# 0          NaN    1.0    2.0        1.0
# 1          NaN    2.0    1.0        1.0
# 2          NaN    2.0    1.0        1.0
# 3          NaN    2.0    1.0        1.0
# 4          NaN    1.0    2.0        1.0
# ...        ...    ...    ...        ...
# 67851      NaN    1.0    2.0        1.0
# 67852      NaN    2.0    1.0        1.0
# 67853      NaN    2.0    1.0        1.0
# 67854      NaN    1.0    2.0        1.0
# 67855      NaN    1.0    2.0        1.0
#
# [67856 rows x 55 columns]

# %%
# PUNTO 1 
# poblacion total 
poblacion_total = (df_cgsse['FEX_C18'].sum())
print(f"la poblacion total es : {poblacion_total} personas")
print("-----------------------------------------------------------------------")
print("RESPUESTA:")
print("La población total de referencia para Colombia basado en el") 
print("modulo cgsse de la GEIH y el factor de expansion es 52´042.001 personas")
# Out:
# la poblacion total es : 52045001.000009045 personas
# -----------------------------------------------------------------------
# RESPUESTA:
# La población total de referencia para Colombia basado en el
# modulo cgsse de la GEIH y el factor de expansion es 52´042.001 personas

# %%
#poblacion en edad de trabajar 
PET = df_cgsse[df_cgsse["P6040"] >= 15] ["FEX_C18"].sum()
print(f"el total de personas en edad de trabajar es : {PET} personas")
print("---------------------------------------------------------------------")
print("RESPUESTA:")
print("el total de la poblacion en edad de trabajar basado en el modulo cgsse de")
print("la GEIH y el indicador P6040 de las personas con una edad mayor o igual") 
print("a 15 años y el factor de expancion es de 40´653.416 personas")
# Out:
# el total de personas en edad de trabajar es : 40653416.00000409 personas
# ---------------------------------------------------------------------
# RESPUESTA:
# el total de la poblacion en edad de trabajar basado en el modulo cgsse de
# la GEIH y el indicador P6040 de las personas con una edad mayor o igual
# a 15 años y el factor de expancion es de 40´653.416 personas

# %%
# poblacion que no esta en edad de trabajar 
PNET = df_cgsse[df_cgsse["P6040"] < 15] ["FEX_C18"].sum()
print(f'Poblacion que no esta en edad de trabajar {PNET}')
print("-----------------------------------------------------------------------")
print("RESPUESTA:")
print("el total de la poblacion que no esta en edad de trabajar basado en el modulo") 
print("cgsse de la GEIH y el indicador P6040 de las personas con una edad menor") 
print("a 15 años y el factor de expancion es de 11´391.585 personas")
# Out:
# Poblacion que no esta en edad de trabajar 11391585.000004958
# -----------------------------------------------------------------------
# RESPUESTA:
# el total de la poblacion que no esta en edad de trabajar basado en el modulo
# cgsse de la GEIH y el indicador P6040 de las personas con una edad menor
# a 15 años y el factor de expancion es de 11´391.585 personas

# %%
# poblacion economicamente activa
PEA=df_ft[(df_ft['FT']==1)]['FEX_C18'].sum()
print(f'Población Economicamente Activa {PEA}')
print("---------------------------------------------------------------------------")
print("RESPUESTA:")
print("el total de la poblacion economicamente activa (PEA) basado en el modulo")
print("ft de la GEIH y el indicador FT de las personas que estan ocupadas o") 
print("buscan trabajo y el factor de expancion es de 25´974.846 personas")
# Out:
# Población Economicamente Activa 25974846.22356785
# ---------------------------------------------------------------------------
# RESPUESTA:
# el total de la poblacion economicamente activa (PEA) basado en el modulo
# ft de la GEIH y el indicador FT de las personas que estan ocupadas o
# buscan trabajo y el factor de expancion es de 25´974.846 personas

# %%
PEI=df_ft[(df_ft['FFT']==1)]['FEX_C18'].sum()
print(f'Población Economicamente Inactiva: {PEI}')
print("------------------------------------------------------------------------------")
print("RESPUESTA:")
print("el total de la poblacion economicamente inactiva (PEI) basado en el modulo")
print("ft de la GEIH y el indicador FFT de las personas que estan en edad de trabajar") 
print("y no buscan trabajo y el factor de expancion es de 14´678.569 personas")
# Out:
# Población Economicamente Inactiva: 14678569.776436238
# ------------------------------------------------------------------------------
# RESPUESTA:
# el total de la poblacion economicamente inactiva (PEI) basado en el modulo
# ft de la GEIH y el indicador FFT de las personas que estan en edad de trabajar
# y no buscan trabajo y el factor de expancion es de 14´678.569 personas

# %%
# tasa de ocupacion 
O=df_ocupados[(df_ocupados['OCI']==1)]['FEX_C18'].sum()
T_ocupacion = O/PET*100
print(f' Tasa de ocupacion para Diciembre de 2025 : {round(T_ocupacion,1)}')
print("----------------------------------------------------------------------")
print("RESPUESTA:")
print("basandonos en el modulo ocupados de la GEIH y el indicador OCI para")
print("determinar el total de personas que ocupadas (O) y el ")
print("factor de expancion, aplicando la formula, la tasa de ocupacion para") 
print("colombia en diciembre de 2025 es de 58.4%")
# Out:
#  Tasa de ocupacion para Diciembre de 2025 : 58.4
# ----------------------------------------------------------------------
# RESPUESTA:
# basandonos en el modulo ocupados de la GEIH y el indicador OCI para
# determinar el total de personas que ocupadas (O) y el
# factor de expancion, aplicando la formula, la tasa de ocupacion para
# colombia en diciembre de 2025 es de 58.4%

# %%
# tasa de desempleo
D = df_desocupados[(df_desocupados['DSI']==1)]['FEX_C18'].sum()
T_desempleo = D/PEA*100
print(f' Tasa de desempleo para Diciembre de 2025 : {round(T_desempleo,1)}')
print("---------------------------------------------------")
print("RESPUESTA")
print("basandonos en el modulo desocupados de la GEIH y el indicador DSI para") 
print("determinar el total de personas que desocupadas (D) y el") 
print("factor de expancion, aplicando la formula, la tasa de desempleo para") 
print("diciembre de 2025 es de 8.6%")
# Out:
#  Tasa de desempleo para Diciembre de 2025 : 8.6
# ---------------------------------------------------
# RESPUESTA
# basandonos en el modulo desocupados de la GEIH y el indicador DSI para
# determinar el total de personas que desocupadas (D) y el
# factor de expancion, aplicando la formula, la tasa de desempleo para
# diciembre de 2025 es de 8.6%

# %%
df_desocupados = df_desocupados.drop(columns=['P3271','P6040'], errors='ignore')
df_ft = df_ft.drop(columns=['P3271','P6040'], errors='ignore')

# %%
# PUNTO 2
# TD Risaralda hombres
df_desocupados = pd.merge(df_desocupados, df_cgsse[['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'P3271','P6040']], 
                        on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how='left')

df_ft = pd.merge(df_ft, df_cgsse[['DIRECTORIO', 'SECUENCIA_P', 'ORDEN', 'P3271','P6040']], 
                        on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how='left')

# %%
# TD Risaralda Hombres
HDR = df_desocupados[(df_desocupados['DSI']==1) 
                     & (df_desocupados['DPTO']==66) 
                     & (df_desocupados['P3271']==1)]['FEX_C18'].sum()
PEAHR = df_ft[(df_ft['FT']==1) 
              & (df_ft['DPTO']==66) 
              & (df_ft['P3271']==1) ]['FEX_C18'].sum()
TDHR = HDR/PEAHR
print(f'Hombres Desempleados en Risaralda: {HDR}')
print(f'Poblacion Economicamente Activa de hombres en Risaralda: {PEAHR}')
print(f'Tasa de Desempleo en hombres de Risaralda: {TDHR*100}%')
print("---------------------------------------------------")
print("RESPUESTA")
print("la tasa de desempleo para los hombres de Risaralda es de 6.07% ")
# Out:
# Hombres Desempleados en Risaralda: 18000.60370715
# Poblacion Economicamente Activa de hombres en Risaralda: 296342.328368219
# Tasa de Desempleo en hombres de Risaralda: 6.074260064793518%
# ---------------------------------------------------
# RESPUESTA
# la tasa de desempleo para los hombres de Risaralda es de 6.07%

# %%
# TD Risaralda Mujeres 
MDR = df_desocupados[(df_desocupados['DSI']==1) 
                     & (df_desocupados['DPTO']==66) 
                     & (df_desocupados['P3271']==2)]['FEX_C18'].sum()
PEAMR = df_ft[(df_ft['FT']==1) 
              & (df_ft['DPTO']==66) 
              & (df_ft['P3271']==2) ]['FEX_C18'].sum()
TDMR = MDR/PEAMR
print(f'Mujeres Desempleadas en Risaralda: {MDR}')
print(f'Poblacion Economicamente Activa de Mujeres en Risaralda: {PEAMR}')
print(f'Tasa de Desempleo en Mujeres de Risaralda: {TDMR*100}%')
print("---------------------------------------------------")
print("RESPUESTA")
print("la tasa de desempleo para las mujeres de Risaralda es de 10.66% ")
# Out:
# Mujeres Desempleadas en Risaralda: 21676.799766712
# Poblacion Economicamente Activa de Mujeres en Risaralda: 203157.903399127
# Tasa de Desempleo en Mujeres de Risaralda: 10.669926891362644%
# ---------------------------------------------------
# RESPUESTA
# la tasa de desempleo para las mujeres de Risaralda es de 10.66%

# %%
# TD Caldas Hombres
HDC = df_desocupados[(df_desocupados['DSI']==1) 
                     & (df_desocupados['DPTO']==17) 
                     & (df_desocupados['P3271']==1)]['FEX_C18'].sum()
PEAHC = df_ft[(df_ft['FT']==1) 
              & (df_ft['DPTO']==17) 
              & (df_ft['P3271']==1) ]['FEX_C18'].sum()
TDHC = HDC/PEAHC
print(f'Hombres Desempleados en Caldas: {HDC}')
print(f'Poblacion Economicamente Activa de hombres en Caldas: {PEAHC}')
print(f'Tasa de Desempleo en hombres de Caldas: {TDHC*100}%')
print("---------------------------------------------------")
print("RESPUESTA")
print("la tasa de desempleo para los hombres de Caldas es de 5.58% ")
# Out:
# Hombres Desempleados en Caldas: 18226.160047418998
# Poblacion Economicamente Activa de hombres en Caldas: 326447.467769983
# Tasa de Desempleo en hombres de Caldas: 5.5831831601957065%
# ---------------------------------------------------
# RESPUESTA
# la tasa de desempleo para los hombres de Caldas es de 5.58%

# %%
# TD Caldas Mujeres 
MDC = df_desocupados[(df_desocupados['DSI']==1) 
                     & (df_desocupados['DPTO']==17) 
                     & (df_desocupados['P3271']==2)]['FEX_C18'].sum()
PEAMC = df_ft[(df_ft['FT']==1) 
              & (df_ft['DPTO']==17) 
              & (df_ft['P3271']==2) ]['FEX_C18'].sum()
TDMC = MDC/PEAMC
print(f'Mujeres Desempleadas en Caldas: {MDC}')
print(f'Poblacion Economicamente Activa de Mujeres en Caldas: {PEAMR}')
print(f'Tasa de Desempleo en Mujeres de Caldas: {TDMC*100}%')
print("---------------------------------------------------")
print("RESPUESTA")
print("la tasa de desempleo para las mujeres de Caldas es de 7.67% ")
# Out:
# Mujeres Desempleadas en Caldas: 17214.491449226003
# Poblacion Economicamente Activa de Mujeres en Caldas: 203157.903399127
# Tasa de Desempleo en Mujeres de Caldas: 7.677961547053494%
# ---------------------------------------------------
# RESPUESTA
# la tasa de desempleo para las mujeres de Caldas es de 7.67%

# %%
# TD Tolima Hombres
HDT = df_desocupados[(df_desocupados['DSI']==1) 
                     & (df_desocupados['DPTO']==73) 
                     & (df_desocupados['P3271']==1)]['FEX_C18'].sum()
PEAHT = df_ft[(df_ft['FT']==1) 
              & (df_ft['DPTO']==73) 
              & (df_ft['P3271']==1) ]['FEX_C18'].sum()
TDHT = HDT/PEAHT
print(f'Hombres Desempleados en Tolima : {HDT}')
print(f'Poblacion Economicamente Activa de hombres en el Tolima : {PEAHT}')
print(f'Tasa de Desempleo en hombres del Tolima : {TDHT*100}%')
print("---------------------------------------------------")
print("RESPUESTA")
print("la tasa de desempleo para los hombres del Tolima es de 7.22% ")
# Out:
# Hombres Desempleados en Tolima : 28255.96613253
# Poblacion Economicamente Activa de hombres en el Tolima : 391325.28931057
# Tasa de Desempleo en hombres del Tolima : 7.220582697916321%
# ---------------------------------------------------
# RESPUESTA
# la tasa de desempleo para los hombres del Tolima es de 7.22%

# %%
# TD Tolima Mujeres 
MDT = df_desocupados[(df_desocupados['DSI']==1) 
                     & (df_desocupados['DPTO']==73) 
                     & (df_desocupados['P3271']==2)]['FEX_C18'].sum()
PEAMT = df_ft[(df_ft['FT']==1) 
              & (df_ft['DPTO']==73) 
              & (df_ft['P3271']==2) ]['FEX_C18'].sum()
TDMT = MDT/PEAMT
print(f'Mujeres Desempleadas en Tolima : {MDT}')
print(f'Poblacion Economicamente Activa de Mujeres en el Tolima : {PEAMT}')
print(f'Tasa de Desempleo en Mujeres del tolima: {TDMT*100}%')
print("---------------------------------------------------")
print("RESPUESTA")
print("la tasa de desempleo para las mujeres del Tolima es de 19.2% ")
# Out:
# Mujeres Desempleadas en Tolima : 52100.16756370999
# Poblacion Economicamente Activa de Mujeres en el Tolima : 271316.21571268
# Tasa de Desempleo en Mujeres del tolima: 19.20274740190366%
# ---------------------------------------------------
# RESPUESTA
# la tasa de desempleo para las mujeres del Tolima es de 19.2%

# %%
# TD Quindío Hombres
HDQ = df_desocupados[(df_desocupados['DSI']==1) 
                     & (df_desocupados['DPTO']==63) 
                     & (df_desocupados['P3271']==1)]['FEX_C18'].sum()
PEAHQ = df_ft[(df_ft['FT']==1) 
              & (df_ft['DPTO']==63) 
              & (df_ft['P3271']==1) ]['FEX_C18'].sum()
TDHQ = HDQ/PEAHQ
print(f'Hombres Desempleados en Quindío : {HDQ}')
print(f'Poblacion Economicamente Activa de hombres en el Quindío : {PEAHQ}')
print(f'Tasa de Desempleo en hombres del Quindío : {TDHQ*100}%')
print("---------------------------------------------------")
print("RESPUESTA")
print("la tasa de desempleo para los hombres del Quindio es de 10.23% ")
# Out:
# Hombres Desempleados en Quindío : 17869.520960767004
# Poblacion Economicamente Activa de hombres en el Quindío : 174625.87195169798
# Tasa de Desempleo en hombres del Quindío : 10.233031773040919%
# ---------------------------------------------------
# RESPUESTA
# la tasa de desempleo para los hombres del Quindio es de 10.23%

# %%
# TD Quindío Mujeres 
MDQ = df_desocupados[(df_desocupados['DSI']==1) 
                     & (df_desocupados['DPTO']==63) 
                     & (df_desocupados['P3271']==2)]['FEX_C18'].sum()
PEAMQ = df_ft[(df_ft['FT']==1) 
              & (df_ft['DPTO']==63) 
              & (df_ft['P3271']==2) ]['FEX_C18'].sum()
TDMQ = MDQ/PEAMQ
print(f'Mujeres Desempleadas en el Quindío : {MDQ}')
print(f'Poblacion Economicamente Activa de Mujeres en el Quindío : {PEAMQ}')
print(f'Tasa de Desempleo en Mujeres del Quindío : {TDMQ*100}%')
print("---------------------------------------------------")
print("RESPUESTA")
print("la tasa de desempleo para las mujeres del Quindio es de 9.08% ")
# Out:
# Mujeres Desempleadas en el Quindío : 10618.534945967001
# Poblacion Economicamente Activa de Mujeres en el Quindío : 116885.879263648
# Tasa de Desempleo en Mujeres del Quindío : 9.084531863781265%
# ---------------------------------------------------
# RESPUESTA
# la tasa de desempleo para las mujeres del Quindio es de 9.08%

# %%
print("RESPUESTA")
print("en terminos generales en departamento que menor tasa de desempleo presenta es Caldas")
print("con una tasa 5.58% en hombres y 7.67% en mujeres, y el que una mayor tasa de desempleo presenta")
print("es el departamento del Tolima con una tasa de 7.22% en hombres y un 19.2% en mujeres")
# Out:
# RESPUESTA
# en terminos generales en departamento que menor tasa de desempleo presenta es Caldas
# con una tasa 5.58% en hombres y 7.67% en mujeres, y el que una mayor tasa de desempleo presenta
# es el departamento del Tolima con una tasa de 7.22% en hombres y un 19.2% en mujeres

# %%
# PUNTO 3
# Departamento de Risaralda
a = 66

# grupos de edad
grupos = [(18,24),(24,30),(30,40),(40,50)]

for b, c in grupos:

    # 1. Personas desempleadas
    D = df_desocupados[(df_desocupados['DSI']==1) &
                       (df_desocupados['P6040']>=b) &
                       (df_desocupados['P6040']<=c) &
                       (df_desocupados['DPTO']==a)]['FEX_C18'].sum()
    
    print(f'Personas Desempleadas en Risaralda entre los {b} - {c} años: {D}')

    # 2. PEA
    PEA = df_ft[(df_ft['FT']==1) &
                (df_ft['P6040']>=b) &
                (df_ft['P6040']<=c) &
                (df_ft['DPTO']==a)]['FEX_C18'].sum()
    
    print(f'Poblacion Economicamente Activa en Risaralda entre los {b} - {c} años: {PEA}')

    # 3. Tasa de desempleo
    TD = D/PEA
    print(f'Tasa de Desempleo en personas entre los {b} - {c} en Risaralda: {TD*100}%')
    print('---')


# grupo 60 en adelante
D = df_desocupados[(df_desocupados['DSI']==1) &
                   (df_desocupados['P6040']>=60) &
                   (df_desocupados['DPTO']==a)]['FEX_C18'].sum()

PEA = df_ft[(df_ft['FT']==1) &
            (df_ft['P6040']>=60) &
            (df_ft['DPTO']==a)]['FEX_C18'].sum()

TD = D/PEA

print(f'Personas Desempleadas en Risaralda mayores de 60: {D}')
print(f'Poblacion Economicamente Activa en Risaralda mayores de 60: {PEA}')
print(f'Tasa de Desempleo mayores de 60 en Risaralda: {TD*100}%')
print("-------------------------------------------------------------------")
print("RESPUESTA")
print("Menor tasa de desempleo : poblacion mayor de 60 años con un 3.63%")
print("Mayor tasa de desempleo : poblacion entre los 18 y 24 años con un 14.79%")
# Out:
# Personas Desempleadas en Risaralda entre los 18 - 24 años: 9385.755003442
# Poblacion Economicamente Activa en Risaralda entre los 18 - 24 años: 63454.922070486005
# Tasa de Desempleo en personas entre los 18 - 24 en Risaralda: 14.79121665773423%
# ---
# Personas Desempleadas en Risaralda entre los 24 - 30 años: 10504.69809363
# Poblacion Economicamente Activa en Risaralda entre los 24 - 30 años: 90684.88337600001
# Tasa de Desempleo en personas entre los 24 - 30 en Risaralda: 11.5837366742538%
# ---
# Personas Desempleadas en Risaralda entre los 30 - 40 años: 9922.605545110002
# Poblacion Economicamente Activa en Risaralda entre los 30 - 40 años: 153899.63411428098
# Tasa de Desempleo en personas entre los 30 - 40 en Risaralda: 6.447452329705859%
# ---
# Personas Desempleadas en Risaralda entre los 40 - 50 años: 7584.87602931
# Poblacion Economicamente Activa en Risaralda entre los 40 - 50 años: 103397.01806552199
# Tasa de Desempleo en personas entre los 40 - 50 en Risaralda: 7.3356816001245955%
# ---
# Personas Desempleadas en Risaralda mayores de 60: 2221.4456352800003
# Poblacion Economicamente Activa en Risaralda mayores de 60: 61031.061322139
# Tasa de Desempleo mayores de 60 en Risaralda: 3.6398607318240614%
# -------------------------------------------------------------------
# RESPUESTA
# Menor tasa de desempleo : poblacion mayor de 60 años con un 3.63%
# Mayor tasa de desempleo : poblacion entre los 18 y 24 años con un 14.79%

# %%
# Departamento de Caldas
a = 17

# grupos de edad
grupos = [(18,24),(24,30),(30,40),(40,50),(50,60)]

for b, c in grupos:

    # 1. Personas desempleadas
    D = df_desocupados[(df_desocupados['DSI']==1) &
                       (df_desocupados['P6040']>=b) &
                       (df_desocupados['P6040']<=c) &
                       (df_desocupados['DPTO']==a)]['FEX_C18'].sum()
    
    print(f'Personas Desempleadas en Caldas entre los {b} - {c} años: {D}')

    # 2. PEA
    PEA = df_ft[(df_ft['FT']==1) &
                (df_ft['P6040']>=b) &
                (df_ft['P6040']<=c) &
                (df_ft['DPTO']==a)]['FEX_C18'].sum()
    
    print(f'Poblacion Economicamente Activa en Caldas entre los {b} - {c} años: {PEA}')

    # 3. Tasa de desempleo
    TD = D/PEA
    print(f'Tasa de Desempleo en personas entre los {b} - {c} en Caldas: {TD*100}%')

    print('---')


# grupo 60 en adelante
D = df_desocupados[(df_desocupados['DSI']==1) &
                   (df_desocupados['P6040']>=60) &
                   (df_desocupados['DPTO']==a)]['FEX_C18'].sum()

PEA = df_ft[(df_ft['FT']==1) &
            (df_ft['P6040']>=60) &
            (df_ft['DPTO']==a)]['FEX_C18'].sum()

TD = D/PEA

print(f'Personas Desempleadas en Caldas mayores de 60: {D}')
print(f'Poblacion Economicamente Activa en Caldas mayores de 60: {PEA}')
print(f'Tasa de Desempleo mayores de 60 en Caldas: {TD*100}%')
print("-------------------------------------------------------------------")
print("RESPUESTA")
print("Menor tasa de desempleo : poblacion mayor de 60 años con un 4.06%")
print("Mayor tasa de desempleo : poblacion entre los 18 y 24 años con un 9.34%")
# Out:
# Personas Desempleadas en Caldas entre los 18 - 24 años: 6259.083688154001
# Poblacion Economicamente Activa en Caldas entre los 18 - 24 años: 66978.254075637
# Tasa de Desempleo en personas entre los 18 - 24 en Caldas: 9.344949005517167%
# ---
# Personas Desempleadas en Caldas entre los 24 - 30 años: 6090.488353998
# Poblacion Economicamente Activa en Caldas entre los 24 - 30 años: 94541.70353229
# Tasa de Desempleo en personas entre los 24 - 30 en Caldas: 6.442118267858205%
# ---
# Personas Desempleadas en Caldas entre los 30 - 40 años: 7691.5534119310005
# Poblacion Economicamente Activa en Caldas entre los 30 - 40 años: 134487.41843531598
# Tasa de Desempleo en personas entre los 30 - 40 en Caldas: 5.719162060970324%
# ---
# Personas Desempleadas en Caldas entre los 40 - 50 años: 6318.584371157001
# Poblacion Economicamente Activa en Caldas entre los 40 - 50 años: 123334.19349942802
# Tasa de Desempleo en personas entre los 40 - 50 en Caldas: 5.123140786732679%
# ---
# Personas Desempleadas en Caldas entre los 50 - 60 años: 9940.360264870002
# Poblacion Economicamente Activa en Caldas entre los 50 - 60 años: 119280.95067215401
# Tasa de Desempleo en personas entre los 50 - 60 en Caldas: 8.333568946974%
# ---
# Personas Desempleadas en Caldas mayores de 60: 2543.690331052
# Poblacion Economicamente Activa en Caldas mayores de 60: 62637.207145629
# Tasa de Desempleo mayores de 60 en Caldas: 4.060989381499756%
# -------------------------------------------------------------------
# RESPUESTA
# Menor tasa de desempleo : poblacion mayor de 60 años con un 4.06%
# Mayor tasa de desempleo : poblacion entre los 18 y 24 años con un 9.34%

# %%
# Departamento del Tolima
a = 73

# grupos de edad
grupos = [(18,24),(24,30),(30,40),(40,50),(50,60)]

for b, c in grupos:

    # 1. Personas desempleadas
    D = df_desocupados[(df_desocupados['DSI']==1) &
                       (df_desocupados['P6040']>=b) &
                       (df_desocupados['P6040']<=c) &
                       (df_desocupados['DPTO']==a)]['FEX_C18'].sum()
    
    print(f'Personas Desempleadas en el Tolima entre los {b} - {c} años: {D}')

    # 2. PEA
    PEA = df_ft[(df_ft['FT']==1) &
                (df_ft['P6040']>=b) &
                (df_ft['P6040']<=c) &
                (df_ft['DPTO']==a)]['FEX_C18'].sum()
    
    print(f'Poblacion Economicamente Activa en el Tolima entre los {b} - {c} años: {PEA}')

    # 3. Tasa de desempleo
    TD = D/PEA
    print(f'Tasa de Desempleo en personas entre los {b} - {c} en el Tolima: {TD*100}%')

    print('---')


# grupo 60 en adelante
D = df_desocupados[(df_desocupados['DSI']==1) &
                   (df_desocupados['P6040']>=60) &
                   (df_desocupados['DPTO']==a)]['FEX_C18'].sum()

PEA = df_ft[(df_ft['FT']==1) &
            (df_ft['P6040']>=60) &
            (df_ft['DPTO']==a)]['FEX_C18'].sum()

TD = D/PEA

print(f'Personas Desempleadas en el Tolima mayores de 60: {D}')
print(f'Poblacion Economicamente Activa en el Tolima mayores de 60: {PEA}')
print(f'Tasa de Desempleo mayores de 60 en el Tolima: {TD*100}%')
print("-------------------------------------------------------------------")
print("RESPUESTA:")
print("Menor tasa de desempleo : poblacion entre los 50 y 60 años con un 7.15%")
print("Mayor tasa de desempleo : poblacion entre los 18 y 24 años con un 19.81%")
# Out:
# Personas Desempleadas en el Tolima entre los 18 - 24 años: 15908.42272112
# Poblacion Economicamente Activa en el Tolima entre los 18 - 24 años: 80276.38281808
# Tasa de Desempleo en personas entre los 18 - 24 en el Tolima: 19.817064699055017%
# ---
# Personas Desempleadas en el Tolima entre los 24 - 30 años: 12039.076700790001
# Poblacion Economicamente Activa en el Tolima entre los 24 - 30 años: 86718.36533803001
# Tasa de Desempleo en personas entre los 24 - 30 en el Tolima: 13.882960839796077%
# ---
# Personas Desempleadas en el Tolima entre los 30 - 40 años: 18987.559043110003
# Poblacion Economicamente Activa en el Tolima entre los 30 - 40 años: 155035.56353474
# Tasa de Desempleo en personas entre los 30 - 40 en el Tolima: 12.247228061873246%
# ---
# Personas Desempleadas en el Tolima entre los 40 - 50 años: 12768.45231577
# Poblacion Economicamente Activa en el Tolima entre los 40 - 50 años: 147765.20025582
# Tasa de Desempleo en personas entre los 40 - 50 en el Tolima: 8.641041526465289%
# ---
# Personas Desempleadas en el Tolima entre los 50 - 60 años: 9566.76868107
# Poblacion Economicamente Activa en el Tolima entre los 50 - 60 años: 133668.70757986998
# Tasa de Desempleo en personas entre los 50 - 60 en el Tolima: 7.157074272864983%
# ---
# Personas Desempleadas en el Tolima mayores de 60: 9913.257434480001
# Poblacion Economicamente Activa en el Tolima mayores de 60: 104806.45873117
# Tasa de Desempleo mayores de 60 en el Tolima: 9.458632182113549%
# -------------------------------------------------------------------
# RESPUESTA:
# Menor tasa de desempleo : poblacion entre los 50 y 60 años con un 7.15%
# Mayor tasa de desempleo : poblacion entre los 18 y 24 años con un 19.81%

# %%
# Departamento del Quindio
a = 63

# grupos de edad
grupos = [(18,24),(24,30),(30,40),(40,50),(50,60)]

for b, c in grupos:

    # 1. Personas desempleadas
    D = df_desocupados[(df_desocupados['DSI']==1) &
                       (df_desocupados['P6040']>=b) &
                       (df_desocupados['P6040']<=c) &
                       (df_desocupados['DPTO']==a)]['FEX_C18'].sum()
    
    print(f'Personas Desempleadas en el Quindio entre los {b} - {c} años: {D}')

    # 2. PEA
    PEA = df_ft[(df_ft['FT']==1) &
                (df_ft['P6040']>=b) &
                (df_ft['P6040']<=c) &
                (df_ft['DPTO']==a)]['FEX_C18'].sum()
    
    print(f'Poblacion Economicamente Activa en el Quindio entre los {b} - {c} años: {PEA}')

    # 3. Tasa de desempleo
    TD = D/PEA
    print(f'Tasa de Desempleo en personas entre los {b} - {c} en el Quindio: {TD*100}%')

    print('---')


# grupo 60 en adelante
D = df_desocupados[(df_desocupados['DSI']==1) &
                   (df_desocupados['P6040']>=60) &
                   (df_desocupados['DPTO']==a)]['FEX_C18'].sum()

PEA = df_ft[(df_ft['FT']==1) &
            (df_ft['P6040']>=60) &
            (df_ft['DPTO']==a)]['FEX_C18'].sum()

TD = D/PEA

print(f'Personas Desempleadas en Quindio mayores de 60: {D}')
print(f'Poblacion Economicamente Activa en el Quindio mayores de 60: {PEA}')
print(f'Tasa de Desempleo mayores de 60 en el Quindio: {TD*100}%')
print("-------------------------------------------------------------------")
print("RESPUESTA:")
print("Menor tasa de desempleo : poblacion entre los 40 y 50 años con un 6.25%")
print("Mayor tasa de desempleo : poblacion entre los 24 y 30 años con un 13.7%")
# Out:
# Personas Desempleadas en el Quindio entre los 18 - 24 años: 3819.2724449800003
# Poblacion Economicamente Activa en el Quindio entre los 18 - 24 años: 29912.663758397
# Tasa de Desempleo en personas entre los 18 - 24 en el Quindio: 12.768078683423386%
# ---
# Personas Desempleadas en el Quindio entre los 24 - 30 años: 7008.068900358
# Poblacion Economicamente Activa en el Quindio entre los 24 - 30 años: 51117.425383347
# Tasa de Desempleo en personas entre los 24 - 30 en el Quindio: 13.709745449427672%
# ---
# Personas Desempleadas en el Quindio entre los 30 - 40 años: 7015.512022579001
# Poblacion Economicamente Activa en el Quindio entre los 30 - 40 años: 72731.96687714598
# Tasa de Desempleo en personas entre los 30 - 40 en el Quindio: 9.645706453159914%
# ---
# Personas Desempleadas en el Quindio entre los 40 - 50 años: 4416.562673204001
# Poblacion Economicamente Activa en el Quindio entre los 40 - 50 años: 70586.28939453498
# Tasa de Desempleo en personas entre los 40 - 50 en el Quindio: 6.256969605695048%
# ---
# Personas Desempleadas en el Quindio entre los 50 - 60 años: 4360.422246094
# Poblacion Economicamente Activa en el Quindio entre los 50 - 60 años: 53694.532340102
# Tasa de Desempleo en personas entre los 50 - 60 en el Quindio: 8.120793786739808%
# ---
# Personas Desempleadas en Quindio mayores de 60: 4297.130465619
# Poblacion Economicamente Activa en el Quindio mayores de 60: 41690.707895215004
# Tasa de Desempleo mayores de 60 en el Quindio: 10.307165991086942%
# -------------------------------------------------------------------
# RESPUESTA:
# Menor tasa de desempleo : poblacion entre los 40 y 50 años con un 6.25%
# Mayor tasa de desempleo : poblacion entre los 24 y 30 años con un 13.7%

# %%
# PUNTO 4
# Departamentos
departamentos = {
    "Risaralda":66,
    "Caldas":17,
    "Tolima":73,
    "Quindio":63
}

resultados = {}

for nombre, codigo in departamentos.items():
    
    # Mujeres desempleadas 18-25
    D = df_desocupados[(df_desocupados['DSI']==1) &
                       (df_desocupados['P3271']==2) &
                       (df_desocupados['P6040']>=18) &
                       (df_desocupados['P6040']<=25) &
                       (df_desocupados['DPTO']==codigo)]['FEX_C18'].sum()
    
    # PEA mujeres 18-25
    PEA = df_ft[(df_ft['FT']==1) &
                (df_ft['P3271']==2) &
                (df_ft['P6040']>=18) &
                (df_ft['P6040']<=25) &
                (df_ft['DPTO']==codigo)]['FEX_C18'].sum()
    
    TD = D/PEA
    resultados[nombre] = TD
    
    print(f"Tasa de desempleo mujeres 18-25 en {nombre}: {TD*100}%")

# Departamento con menor tasa
menor = min(resultados, key=resultados.get)

print("------------------------------------------------")
print("RESPUESTA:")
print("El departamento con menor tasa de desempleo de mujeres entre 18 y 25 años es el Quindio")
print("con una tasa de 7.46%")
# Out:
# Tasa de desempleo mujeres 18-25 en Risaralda: 22.992769133081296%
# Tasa de desempleo mujeres 18-25 en Caldas: 14.50010240532998%
# Tasa de desempleo mujeres 18-25 en Tolima: 21.37807100891119%
# Tasa de desempleo mujeres 18-25 en Quindio: 7.468210722605588%
# ------------------------------------------------
# RESPUESTA:
# El departamento con menor tasa de desempleo de mujeres entre 18 y 25 años es el Quindio
# con una tasa de 7.46%

# %%
# PUNTO 5
# Departamento Quindio
# Hombres en edad de trabajar
H = df_cgsse[(df_cgsse['P6040']>=15) &
             (df_cgsse['P3271']==1) &
             (df_cgsse['DPTO']==63)]['FEX_C18'].sum()

print(f'Hombres en edad de trabajar en el Quindio: {H}')

# Mujeres en edad de trabajar
M = df_cgsse[(df_cgsse['P6040']>=15) &
             (df_cgsse['P3271']==2) &
             (df_cgsse['DPTO']==63)]['FEX_C18'].sum()

print(f'Mujeres en edad de trabajar en el Quindio: {M}')

# Total población Quindio 
PTQ = df_cgsse[(df_cgsse['DPTO']==63)]['FEX_C18'].sum()

print(f'Poblacion total en el Quindio: {PTQ}')

# Porcentajes
PH = (H/PTQ)*100
PM = (M/PTQ)*100

print(f'Porcentaje de hombres en edad de trabajar: {PH}%')
print(f'Porcentaje de mujeres en edad de trabajar: {PM}%')
print("-----------------------------------------------------")
print("RESPUESTA")
print("realizando el analisis con el modulo cgsse de la GEIH, y los indicadores")
print("P6040 para determinar la pobacion en edad de trabajar, P3271 para discriminar por sexo")
print("DPTO para seleccionar del total nacional solo al departamento del Quindio podemos concluir")
print("que actualmente existen 247.037 hombres y 261.387 mujeres en edad de trabajar, los cuales")
print("representan el 40.96% y 43.34% de la poblacion total respectivamente ")
# Out:
# Hombres en edad de trabajar en el Quindio: 247037.510834763
# Mujeres en edad de trabajar en el Quindio: 261387.92755063402
# Poblacion total en el Quindio: 603068.649439007
# Porcentaje de hombres en edad de trabajar: 40.96341454071023%
# Porcentaje de mujeres en edad de trabajar: 43.34298057008685%
# -----------------------------------------------------
# RESPUESTA
# realizando el analisis con el modulo cgsse de la GEIH, y los indicadores
# P6040 para determinar la pobacion en edad de trabajar, P3271 para discriminar por sexo
# DPTO para seleccionar del total nacional solo al departamento del Quindio podemos concluir
# que actualmente existen 247.037 hombres y 261.387 mujeres en edad de trabajar, los cuales
# representan el 40.96% y 43.34% de la poblacion total respectivamente

# %%
# PUNTO 6
# Departamento Tolima
# Poblacion en edad de trabajar
PETT = df_cgsse[(df_cgsse['P6040']>=15) &
               (df_cgsse['DPTO']==73)]['FEX_C18'].sum()

print(f'Poblacion en edad de trabajar en Tolima: {PET}')

# Poblacion total
PTT = df_cgsse[(df_cgsse['DPTO']==73)]['FEX_C18'].sum()

print(f'Poblacion total en Tolima: {PTT}')

# Porcentaje
Porcentaje = (PETT/PTT)*100

print(f'Porcentaje de la poblacion del Tolima en edad de trabajar: {Porcentaje}%')
print("-----------------------------------------------------")
print("RESPUESTA")
print("realizando un analisis con el modulo cgsse de la GEIH, y los indicadores")
print("P6040 y DPTO, apicando elfactor de expancion para determinar la poblacion en edad de")
print("trabajar en el departamento del Tolima y aplicandole el factor de expancion al indicador ")
print("DPTO para obtener el total de la poblacion del tolima, obtenemos que el 77.01% del total")
print("de la poblacion del Tolima esta en edad de trabajar.")
# Out:
# Poblacion en edad de trabajar en Tolima: 40653416.00000409
# Poblacion total en Tolima: 1411965.04428173
# Porcentaje de la poblacion del Tolima en edad de trabajar: 77.01034018103488%
# -----------------------------------------------------
# RESPUESTA
# realizando un analisis con el modulo cgsse de la GEIH, y los indicadores
# P6040 y DPTO, apicando elfactor de expancion para determinar la poblacion en edad de
# trabajar en el departamento del Tolima y aplicandole el factor de expancion al indicador
# DPTO para obtener el total de la poblacion del tolima, obtenemos que el 77.01% del total
# de la poblacion del Tolima esta en edad de trabajar.

# %%
# PUNTO 7
# Departamento Risaralda
# Poblacion Economicamente Inactiva
PEIR = df_ft[(df_ft['FFT']==1) &
            (df_ft['DPTO']==66)]['FEX_C18'].sum()

print(f'Poblacion Economicamente Inactiva en Risaralda: {PEIR}')

# Poblacion en edad de trabajar
PETR = df_cgsse[(df_cgsse['P6040']>=15) &
               (df_cgsse['DPTO']==66)]['FEX_C18'].sum()

print(f'Poblacion en edad de trabajar en Risaralda: {PETR}')

# Porcentaje
Porcentaje = (PEIR/PETR)*100

print(f'Porcentaje de poblacion economicamente inactiva en Risaralda: {Porcentaje}%')
print("-----------------------------------------------------")
print("RESPUESTA")
print("realizando un analisis con los modulos ft y cgsse de la GEIH, y los indicadores")
print("FFT y DPTO, aplicando el factor de expancion para determinar la poblacion economicamante")
print("inactiva del departamento de Risaralda y los indicadores P6040 y DPTO, aplicando el factor ")
print("de expancion para obtner la poblacion en edad de trabajar, podemos inferir que el 39.98% ")
print("de la poblacion del Risaralda es poblacion economicamente incativa.")
# Out:
# Poblacion Economicamente Inactiva en Risaralda: 332743.42055744905
# Poblacion en edad de trabajar en Risaralda: 832243.652324795
# Porcentaje de poblacion economicamente inactiva en Risaralda: 39.981490952554736%
# -----------------------------------------------------
# RESPUESTA
# realizando un analisis con los modulos ft y cgsse de la GEIH, y los indicadores
# FFT y DPTO, aplicando el factor de expancion para determinar la poblacion economicamante
# inactiva del departamento de Risaralda y los indicadores P6040 y DPTO, aplicando el factor
# de expancion para obtner la poblacion en edad de trabajar, podemos inferir que el 39.98%
# de la poblacion del Risaralda es poblacion economicamente incativa.

# %%
#PUNTO 8
# Departamento del Quindio 
# desempleados entre los 18 y 30 años
DQ18_30 = df_desocupados[(df_desocupados['DSI']==1) &
                       (df_desocupados['P6040']>=18) &
                       (df_desocupados['P6040']<=30) &
                       (df_desocupados['DPTO']==63)]['FEX_C18'].sum()
print(f"Personas desempleadas entre los 18 y 30 años en el Quindio: {DQ18_30}")
print("-----------------------------------------------------")
print("RESPUESTA")
print("realizando el analisis con el modulo desocupados de la GEIH, y los indicadores")
print("DSI, P6040 y DPTO, aplicando el factor de expancion podemos determinar que la cantidad de personas")
print("desocupadas entre los 10 y 30 es de 9.479 en el departamento del Quindio")
# Out:
# Personas desempleadas entre los 18 y 30 años en el Quindio: 9479.632579867999
# -----------------------------------------------------
# RESPUESTA
# realizando el analisis con el modulo desocupados de la GEIH, y los indicadores
# DSI, P6040 y DPTO, aplicando el factor de expancion podemos determinar que la cantidad de personas
# desocupadas entre los 10 y 30 es de 9.479 en el departamento del Quindio

# %%
# PUNTO 9
# Departamento del Tolima
# desempleados entre los 20 y 25 años
DT20_25 = df_desocupados[(df_desocupados['DSI']==1) &
                       (df_desocupados['P6040']>=20) &
                       (df_desocupados['P6040']<=25) &
                       (df_desocupados['DPTO']==73)]['FEX_C18'].sum()
print(f"Personas desempleadas entre los 20 y 25 años en el Tolima: {DT20_25}")
# poblacion total del Tolima 
PTT = df_cgsse[(df_cgsse['DPTO']==73)]['FEX_C18'].sum()
print(f'Poblacion total en Tolima: {PTT}')
#porcentaje 
porcentaje = (DT20_25/PTT)*100
print(f"porcetaje de la poblacion desempleada entre los 20 y 25 años en el tolima: {porcentaje}%")
print("-----------------------------------------------------")
print("RESPUESTA")
print("realizando el analisis con los modulos cgsse y desocupados de la GEIH, y los indicadores")
print("DSI, P6040 y DPTO, aplicando el factor de expancion para determinar que la cantidad de personas")
print("desocupadas entre los 10 y 30 en el departamento del Tolima y obteniendo la poblacion total")
print("utilizando el indicador DPTO y aplicandole el factor de expancion, obtenemos que existen 12.622")
print("desempleadas, las cuales representan el 0.39% de la poblacion total del Tolima.")
# Out:
# Personas desempleadas entre los 20 y 25 años en el Tolima: 12622.56937425
# Poblacion total en Tolima: 1411965.04428173
# porcetaje de la poblacion desempleada entre los 20 y 25 años en el tolima: 0.8939718037192013%
# -----------------------------------------------------
# RESPUESTA
# realizando el analisis con los modulos cgsse y desocupados de la GEIH, y los indicadores
# DSI, P6040 y DPTO, aplicando el factor de expancion para determinar que la cantidad de personas
# desocupadas entre los 10 y 30 en el departamento del Tolima y obteniendo la poblacion total
# utilizando el indicador DPTO y aplicandole el factor de expancion, obtenemos que existen 12.622
# desempleadas, las cuales representan el 0.39% de la poblacion total del Tolima.
